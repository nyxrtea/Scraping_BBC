# %%
# Modul yang digunakan untuk wraping

import requests as rs
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os

# %%
import requests as rs
from bs4 import BeautifulSoup

judul = []
url = 'https://www.bbc.com/news'

response = rs.get(url)

# Memeriksa permintaan
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Mencari element di h3 dan h2
    conteny = soup.find_all(['h3', 'h2'])  # Memberi batasan class untuk mencari element

    for t in conteny:
        judul_text = t.get_text(strip=True)
        judul.append(judul_text)
else:
    print(f"Failed to retrieve page: Status code {response.status_code}")

print(judul)
# Out:
# ["Netanyahu tells Israel's military to keep fighting with 'full force' in Lebanon after ceasefire calls", "World's longest-serving death row inmate acquitted in Japan", 'The Kashmiri politician whose return from jail ruffled feathers', "South-eastern US braces for 'catastrophic' Hurricane Helene", 'Watch: Building collapses into river in India', "World's longest-serving death row inmate acquitted in Japan", 'Hong Kong jails two journalists for sedition', "Escalating Trump row looms over Zelensky's US visit", 'Japan sails warship in Taiwan Strait for first time: reports', 'The Kashmiri politician whose return from jail ruffled feathers', 'IMF approves $7bn loan to cash-strapped Pakistan', "Australia's lithium mining boom hit by sagging prices", 'New York City Mayor Eric Adams indicted on federal charges', 'Sudan army launches major attack on capital Khartoum', 'How Fayed built a corrupt system of enablers to carry out his sexual abuse', 'Israeli strikes on Lebanon', 'Iran faces dilemma of restraint or revenge for attacks on ally Hezbollah', 'BBC finds Lebanese seaside city deserted after Israeli attacks', "Britons 'stuck' in Lebanon as PM says 'leave now'", 'What is Hezbollah and why is Israel attacking Lebanon?', 'Bowen: Israel is gambling Hezbollah will crumple but it faces a well-armed, angry enemy', 'More to explore', 'We danced with joy then hid among the dead – Nova survivors recall Hamas massacre', "Death of Indian employee sparks debate on 'toxic work culture'", 'Toiling on a Kenyan flower farm to send fresh roses to Europe', "'Chaos reigns' - the notorious jail holding Sean 'Diddy' Combs", "'The violence is getting out of hand': Crime grips Cuba's streets", "Death of Indian employee sparks debate on 'toxic work culture'", "Why Pakistan's female doctors don't feel safe", 'In Pictures: 10,000 miles across US as seen through train window', 'Toiling on a Kenyan flower farm to send fresh roses to Europe', 'Most watched', 'Watch: Building collapses into river in India', 'We danced with joy then hid among the dead – Nova survivors recall Hamas massacre', 'BBC finds Lebanese seaside city deserted after Israeli attacks', 'Why was the East of England hit by flash flooding?', 'Watch: Hijacked bus chased by police through downtown LA', 'Also in news', "Earth to briefly gain second 'moon', scientists say", 'Murder of Paris student fuels anger at failed deportation', 'Watch: Building collapses into river in India', "China's long-range missile test sparks concerns", 'Eswatini opposition leader poisoned in South Africa, party says', 'Murder of Paris student fuels anger at failed deportation', 'Finland to return pandas to China early due to €1.5m a year cost', 'Hijacked bus chased by police through downtown LA', 'Watch: Building collapses into river in India', 'Most read', "Escalating Trump row looms over Zelensky's US visit", "World's longest-serving death row inmate acquitted in Japan", 'Putin proposes new rules for using nuclear weapons', "'Chaos reigns' - the notorious jail holding Sean 'Diddy' Combs", 'Japan sails warship in Taiwan Strait for first time: reports', 'New York City Mayor Eric Adams indicted on federal charges', "South-eastern US braces for 'catastrophic' Hurricane Helene", 'How Fayed built a corrupt system of enablers to carry out his sexual abuse', 'Musk hits back after being shunned from UK summit', "Australia's lithium mining boom hit by sagging prices", 'Sport', 'Football latest: Premier League manager news conferences coming up', "'Twente wanted it more' - so are Man Utd showing any improvement?", "Heavyweight permutations - what next after Dubois' win?", "From Test match to wedding - Stone's Pakistan dash", 'How many free sports tickets have Starmer and MPs received?', "'Twente wanted it more' - so are Man Utd showing any improvement?", 'Giroud inspires Los Angeles FC to US Open Cup', "Heavyweight permutations - what next after Dubois' win?", 'Follow BBC on:']

# %%
# List untuk menyimpan deskripsi
deskripsi_list = []

# Gabungkan hasil select dari h3 dan h2
headlines = soup.select('h3') + soup.select('h2')

# Ambil deskripsi (jika tersedia) yang terkait dengan headline
for headline in headlines:
    # Cari elemen parent <a> untuk konteks headline
    link_tag = headline.find_parent('a')

    if link_tag:
        # Ambil deskripsi dari elemen <p> yang berada setelah <a>
        deskripsi_tag = link_tag.find_next('p')
        deskripsi_text = deskripsi_tag.get_text(strip=True) if deskripsi_tag else 'No description found'

        # Cek jika deskripsi belum ada dalam list
        if not any(desc['Deskripsi'] == deskripsi_text for desc in deskripsi_list):
            deskripsi_list.append({
                "Deskripsi": deskripsi_text
            })

# Output hasil
if not deskripsi_list:
    print("Tidak ada deskripsi yang ditemukan.")
else:
    for desc in deskripsi_list:
        print(f"Deskripsi: {desc['Deskripsi']}\n")
# Out:
# Deskripsi: The Israeli prime minister's office says Netanyahu has not responded to last night's call for a ceasefire from the US, UK, and other allies.
#
# Deskripsi: After more than half a century on death row Iwao Hakamada, 88, has been acquitted of murder.
#
# Deskripsi: A court has allowed jailed lawmaker Engineer Rashid to return to Kashmir to campaign in regional polls.
#
# Deskripsi: Helene is forecast to intensify to a dangerous category four storm before hitting the US Gulf Coast.
#
# Deskripsi: No-one was injured in the incident, which occurred during heavy rains in Bihar state.
#
# Deskripsi: Editors at a now-defunct news site published articles about the city's national security crackdown.
#
# Deskripsi: Republicans accused Zelensky of election interference, after he visited an arms factory with top Democrats.
#
# Deskripsi: There has been a rise in patrols by the US and its allies who do not accept China's claims over the strait.
#
# Deskripsi: Iran has sought to strike an unusually conciliatory tone in the face of attacks on its ally Hezbollah.
#
# Deskripsi: Correspondent Orla Guerin reports on airstrikes and evacuations in the southern city of Tyre.
#
# Deskripsi: UK nationals tell the BBC they are struggling to get out of Lebanon, after the PM tells them to leave.
#
# Deskripsi: Escalating cross-border hostilities have heightened fears of an all-out conflict.
#
# Deskripsi: The Lebanese armed group has - like Israel - spent years preparing and is more formidable than Hamas in Gaza.
#
# Deskripsi: A new BBC documentary provides a harrowing glimpse into the Hamas attack at the Nova music festival in Israel, in which hundreds of people were killed.
#
# Deskripsi: Anna Perayil's parents allege she died four months after starting a job because of "overwhelming work stress".
#
# Deskripsi: Women work long and gruelling hours to grow the flowers sold across Europe.
#
# Deskripsi: An extensive list of notable names have passed through the doors of the troubled Brooklyn facility
#
# Deskripsi: Fidel Castro once said Cuba was the world's safest nation. Now police can't keep the streets safe.
#
# Deskripsi: Women working in Pakistan’s hospitals say they face sexual harassment, violence and verbal abuse.
#
# Deskripsi: Photographer Katie Edwards captures America from the window of a train.
#
# Deskripsi: Earth is about to get a second moon for a couple of months, but it won't be visible for most people.
#
# Deskripsi: The Moroccan suspect was released from detention after serving five years for raping a student.
#
# Deskripsi: Beijing said the test was "routine" but other countries in the region expressed strong concerns.
#
# Deskripsi: The Pudemo party leader is among the organisers of pro-democracy protests planned for next month.
#
# Deskripsi: Inflation and debt are among the reasons Lumi and Pyry are being sent home eight years early.
#
# Deskripsi: A passenger is killed before a Swat team deployed flash-bang grenades and arrested the suspect.
#
# Deskripsi: All the latest football news as Premier League managers hold news conferences plus build-up to the Europa League action.
#
# Deskripsi: As Manchester United were held to a 1-1 Europa League draw by Twente, BBC Sport looks at what improvements, if any, the Reds are showing this season.
#
# Deskripsi: BBC Sport tries to unravel the heavyweight division and what could happen next after Daniel Dubois scored his shock Wembley win.
#
# Deskripsi: Olly Stone is less than two weeks away from getting married, the only complication is the wedding in Norfolk is the day after England's first Test in Pakistan.
#
# Deskripsi: BBC Sport looks at how many free sports tickets MPs have declared in 2024.
#
# Deskripsi: LAFC keep their domestic double hopes alive with US Open Cup final win against Sporting Kansas City.

# %%
headlines = soup.select('h3, h2')
updates = [] #list untuk menyimpan deskripsi

for headline in headlines:
    link_tag = headline.find_parent('a')

    if link_tag:
        span_tags = link_tag.find_parent().find_all('span')

        last_update_text = 'Last update not found'
        for span in span_tags:
            text = span.get_text(strip=True)
            if text and len(text.split()) > 1:
                last_update_text = text
                break


        updates.append(last_update_text)


if not updates:
    print("Last update not found.")
else:
    for update in updates:
        print(update)
# Out:
# Last update not found
# 3 hrs ago
# 11 hrs ago
# 2 hrs ago
# 5 hrs ago
# 3 hrs ago
# 12 mins ago
# 1 hr ago
# 7 hrs ago
# 11 hrs ago
# 10 hrs ago
# 13 hrs ago
# 7 hrs ago
# 20 mins ago
# 7 hrs ago
# 21 mins ago
# 1 day ago
# 8 hrs ago
# 2 days ago
# 2 days ago
# 15 hrs ago
# 2 days ago
# 11 hrs ago
# 13 hrs ago
# 1 day ago
# 2 days ago
# 2 days ago
# 11 hrs ago
# 11 hrs ago
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# 20 hrs ago
# 23 hrs ago
# 5 hrs ago
# 18 hrs ago
# 22 hrs ago
# 23 hrs ago
# 22 hrs ago
# 19 hrs ago
# 5 hrs ago
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# 12 hrs ago
# 16 hrs ago
# 6 hrs ago
# 1 hr ago
# 12 hrs ago
# 5 hrs ago
# 16 hrs ago

# %%
# Ambil elemen h3 atau h2 dari halaman
headlines = soup.select('h3') + soup.select('h2')

# List untuk menyimpan deskripsi link
link_list = []

for headline in headlines:
    # Cari elemen parent <a> untuk konteks headline
# https://www.bbc.com/news/articles/cp8ejd9l00lo
# https://www.bbc.com/news/articles/c756d56d2dro
# https://www.bbc.com/news/articles/cp8mvmmpmvro
# https://www.bbc.com/sport/football/live/ce8d2380yyet
# https://www.bbc.com/sport/football/articles/c2lnkd7r2y1o
# https://www.bbc.com/sport/boxing/articles/c4gr2gm51zpo
# https://www.bbc.com/sport/cricket/articles/cn7yx3y1rpxo
# https://www.bbc.com/sport/football/articles/ce9j2ky7412o
# https://www.bbc.com/sport/football/articles/c2lnkd7r2y1o
# https://www.bbc.com/sport/football/articles/c4g4rr1llzvo
# https://www.bbc.com/sport/boxing/articles/c4gr2gm51zpo

# %%
# Cari semua elemen gambar
image_tags = soup.find_all('img')

# List untuk menyimpan URL gambar
image = []

# Ambil URL gambar
for img in image_tags:
    image_src = img.get('src')
    if image_src:
        # Jika src relatif, tambahkan domain BBC
        if image_src.startswith('//'):
            full_image_url = f"https:{image_src}"  # Tambahkan "https:" di depan
        elif image_src.startswith('/'):
            full_image_url = f"https://www.bbc.com{image_src}"  # Tambahkan domain utama
        else:
            full_image_url = image_src  # Sudah berupa URL

        # Filter out PNG images
        if not full_image_url.lower().endswith('.png'):
            image.append(full_image_url)

# Cek apakah URL ditemukan
if not image:
    print("Tidak ada URL gambar yang ditemukan.")
else:
    # Tampilkan URL gambar
    for url in image:
        print(url)
# Out:
# https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/e4e4/live/8c9784e0-7bd7-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/f4d2/live/0e318220-7bd9-11ef-b02d-c5f3b724a1ea.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/32c3/live/176bdfc0-7bd9-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/f4d2/live/0e318220-7bd9-11ef-b02d-c5f3b724a1ea.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/7d02/live/2255d710-7bb6-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/bb05/live/6a9a8220-7be6-11ef-a067-535ff32592e2.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/285f/live/f0c4d330-7bb6-11ef-b1e6-b9e53e4962ea.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/32c3/live/176bdfc0-7bd9-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/5dc0/live/c6d35920-7bed-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/c9cb/live/0af13a90-7b31-11ef-b282-4535eb84fe4b.png.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/b7ce/live/31a7e5d0-7bc7-11ef-8c1a-df523ba43a9a.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/3E4C/production/_133584951_9ec3da89c065e433a6dfc285d2e3756e2c9b972f0_254_4928_27731000x563.jpg.webp
