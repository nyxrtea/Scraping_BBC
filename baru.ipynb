# %%
# Modul yang digunakan untuk wraping

import requests as rs
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os

# %%
import requests as rs
from bs4 import BeautifulSoup

judul = []
url = 'https://www.bbc.com/news'

response = rs.get(url)

# Memeriksa permintaan
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Mencari element di h3 dan h2
    conteny = soup.find_all(['h3', 'h2'])  # Memberi batasan class untuk mencari element

    for t in conteny:
        judul_text = t.get_text(strip=True)
        judul.append(judul_text)
else:
    print(f"Failed to retrieve page: Status code {response.status_code}")

print(judul)
# Out:
# ["Netanyahu tells Israel's military to keep fighting with 'full force' in Lebanon after ceasefire calls", "Escalating Trump row looms over Zelensky's US visit", "'Chaos reigns' - the notorious jail holding Sean 'Diddy' Combs", 'Video shows stranded California rafters airlifted to safety', 'How Fayed built a corrupt system of enablers to carry out his sexual abuse', "Escalating Trump row looms over Zelensky's US visit", "South-eastern US braces for 'catastrophic' Hurricane Helene", 'New York City Mayor Eric Adams indicted on federal charges', "World's longest-serving death row inmate acquitted in Japan", "'Chaos reigns' - the notorious jail holding Sean 'Diddy' Combs", 'Putin proposes new rules for using nuclear weapons', 'Japan sails warship in Taiwan Strait for first time: reports', "Australia's lithium mining boom hit by sagging prices", 'Fans fuming after unofficial Bridgerton ball flops', 'Musk hits back after being shunned from UK summit', 'US election 2024', 'Why Georgia could again be centre of an election storm', "Harris promises 'pragmatic' approach in economic pitch to voters", 'US election polls: Who is ahead - Harris or Trump?', 'How social media assassination conspiracies are uniting pro- and anti-Trump voters', 'Crypto world hoping for Trump election win', 'More to explore', '10,000 miles across US as seen through train window', 'How Fayed built a corrupt system of enablers to carry out his sexual abuse', 'The Kashmiri politician whose return from jail ruffled feathers', "Australia's lithium mining boom hit by sagging prices", "'Chaos reigns' - the notorious jail holding Sean 'Diddy' Combs", 'How Fayed built a corrupt system of enablers to carry out his sexual abuse', 'Toiling on a Kenyan flower farm to send fresh roses to Europe', 'We danced with joy then hid among the dead – Nova survivors recall Hamas massacre', 'The Kashmiri politician whose return from jail ruffled feathers', 'Most watched', 'Video shows stranded California rafters airlifted to safety', 'Watch: Hijacked bus chased by police through downtown LA', 'We danced with joy then hid among the dead – Nova survivors recall Hamas massacre', 'BBC finds Lebanese seaside city deserted after Israeli attacks', 'Watch: Building collapses into river in India', 'Most read', "Escalating Trump row looms over Zelensky's US visit", "'Chaos reigns' - the notorious jail holding Sean 'Diddy' Combs", "World's longest-serving death row inmate acquitted in Japan", 'New York City Mayor Eric Adams indicted on federal charges', 'Putin proposes new rules for using nuclear weapons', "South-eastern US braces for 'catastrophic' Hurricane Helene", 'Musk hits back after being shunned from UK summit', 'How Fayed built a corrupt system of enablers to carry out his sexual abuse', 'Fans fuming after unofficial Bridgerton ball flops', 'Japan sails warship in Taiwan Strait for first time: reports', 'Also in news', "Earth to briefly gain second 'moon', scientists say", 'Fans fuming after unofficial Bridgerton ball flops', 'Finland to return pandas to China early due to €1.5m a year cost', "Zelensky looks to Biden to back Ukraine 'victory plan'", 'Hijacked bus chased by police through downtown LA', 'Fans fuming after unofficial Bridgerton ball flops', 'Murder of Paris student fuels anger at failed deportation', "Canada's Trudeau survives no-confidence vote in parliament", "Wuthering Heights and Hollywood's worst casting decision", 'Finland to return pandas to China early due to €1.5m a year cost', 'Watch: Building collapses into river in India', 'Sport', "Football latest: Ten Hag - 'I have to look in the mirror' after Twente draw", "'Twente wanted it more' - so are Man Utd showing any improvement?", "Heavyweight permutations - what next after Dubois' win?", "From Test match to wedding - Stone's Pakistan dash", 'How many free sports tickets have Starmer and MPs received?', "'Twente wanted it more' - so are Man Utd showing any improvement?", 'Giroud inspires Los Angeles FC to US Open Cup', ...

# %%
# List untuk menyimpan deskripsi
deskripsi_list = []

# Gabungkan hasil select dari h3 dan h2
headlines = soup.select('h3') + soup.select('h2')

# Ambil deskripsi (jika tersedia) yang terkait dengan headline
for headline in headlines:
    # Cari elemen parent <a> untuk konteks headline
    link_tag = headline.find_parent('a')

    if link_tag:
        # Ambil deskripsi dari elemen <p> yang berada setelah <a>
        deskripsi_tag = link_tag.find_next('p')
        deskripsi_text = deskripsi_tag.get_text(strip=True) if deskripsi_tag else 'No description found'

        # Cek jika deskripsi belum ada dalam list
        if not any(desc['Deskripsi'] == deskripsi_text for desc in deskripsi_list):
            deskripsi_list.append({
                "Deskripsi": deskripsi_text
            })

# Output hasil
if not deskripsi_list:
    print("Tidak ada deskripsi yang ditemukan.")
else:
    for desc in deskripsi_list:
        print(f"Deskripsi: {desc['Deskripsi']}\n")
# Out:
# Deskripsi: The Israeli prime minister's office says Netanyahu has not responded to last night's call for a ceasefire from the US, UK, and other allies.
#
# Deskripsi: Republicans accused Zelensky of election interference, after he visited an arms factory with top Democrats.
#
# Deskripsi: An extensive list of notable names have passed through the doors of the troubled Brooklyn facility
#
# Deskripsi: All six individuals are safely rescued and handed over to firefighters for medical evaluation.
#
# Deskripsi: Doctors, senior personal assistants and security staff enabled the Harrods owner’s assaults, witnesses say.
#
# Deskripsi: Helene is forecast to intensify to a dangerous category four storm before hitting the US Gulf Coast.
#
# Deskripsi: Adams, 64, is the first mayor in city history to face criminal charges while in office
#
# Deskripsi: After more than half a century on death row Iwao Hakamada, 88, has been acquitted of murder.
#
# Deskripsi: A new Republican rule requiring a hand count of ballots turns the state election board into a political lightning rod.
#
# Deskripsi: Harris is seeking to chip away at Donald Trump's advantage with voters on the economy, a key election issue.
#
# Deskripsi: An in-depth look at the polls and what they can and can’t tell us about who will win the White House.
#
# Deskripsi: A pro-Trump wellness influencer and a suburban Democrat share a conspiracy theory - how did it spread so far?
#
# Deskripsi: Crypto currency firms are waiting to see how November's vote will impact upon them.
#
# Deskripsi: Photographer Katie Edwards captures America from the window of a train.
#
# Deskripsi: A court has allowed jailed lawmaker Engineer Rashid to return to Kashmir to campaign in regional polls.
#
# Deskripsi: Some producers have halted operations, while others are increasing production, hopeful of an upturn.
#
# Deskripsi: Women work long and gruelling hours to grow the flowers sold across Europe.
#
# Deskripsi: A new BBC documentary provides a harrowing glimpse into the Hamas attack at the Nova music festival in Israel, in which hundreds of people were killed.
#
# Deskripsi: Earth is about to get a second moon for a couple of months, but it won't be visible for most people.
#
# Deskripsi: Guests complained they were met with cheap decor, undercooked food and just a stripper for entertainment.
#
# Deskripsi: Inflation and debt are among the reasons Lumi and Pyry are being sent home eight years early.
#
# Deskripsi: Kyiv is hoping for a strong show of support from the US leader before he leaves the White House.
#
# Deskripsi: A passenger is killed before a Swat team deployed flash-bang grenades and arrested the suspect.
#
# Deskripsi: The Moroccan suspect was released from detention after serving five years for raping a student.
#
# Deskripsi: While vote to topple his government has failed, it signals a new series of tests for the prime minister.
#
# Deskripsi: News that Jacob Elordi and Margot Robbie were cast in Emerald Fennell's adaptation was met with strong criticism.
#
# Deskripsi: Reaction as Manchester United held in the Europa League by Twente while Arsenal and Liverpool ease to EFL Cup wins.
#
# Deskripsi: As Manchester United were held to a 1-1 Europa League draw by Twente, BBC Sport looks at what improvements, if any, the Reds are showing this season.
#
# Deskripsi: BBC Sport tries to unravel the heavyweight division and what could happen next after Daniel Dubois scored his shock Wembley win.
#
# Deskripsi: Olly Stone is less than two weeks away from getting married, the only complication is the wedding in Norfolk is the day after England's first Test in Pakistan.
#
# Deskripsi: BBC Sport looks at how many free sports tickets MPs have declared in 2024.
#
# Deskripsi: LAFC keep their domestic double hopes alive with US Open Cup final win against Sporting Kansas City.

# %%
headlines = soup.select('h3, h2')
updates = [] #list untuk menyimpan deskripsi

for headline in headlines:
    link_tag = headline.find_parent('a')

    if link_tag:
        span_tags = link_tag.find_parent().find_all('span')

        last_update_text = 'Last update not found'
        for span in span_tags:
            text = span.get_text(strip=True)
            if text and len(text.split()) > 1:
                last_update_text = text
                break


        updates.append(last_update_text)


if not updates:
    print("Last update not found.")
else:
    for update in updates:
        print(update)
# Out:
# Last update not found
# 40 mins ago
# 13 hrs ago
# 15 hrs ago
# 6 hrs ago
# 40 mins ago
# 1 hr ago
# 6 hrs ago
# 3 hrs ago
# 13 hrs ago
# 1 hr ago
# 6 hrs ago
# 12 hrs ago
# 19 hrs ago
# 13 mins ago
# 14 hrs ago
# 8 hrs ago
# 16 mins ago
# 4 days ago
# 2 days ago
# 11 hrs ago
# 6 hrs ago
# 10 hrs ago
# 12 hrs ago
# 13 hrs ago
# 6 hrs ago
# 10 hrs ago
# 14 hrs ago
# 10 hrs ago
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# Last update not found
# 20 hrs ago
# 19 hrs ago
# 22 hrs ago
# 1 day ago
# 18 hrs ago
# 19 hrs ago
# 23 hrs ago
# 14 hrs ago
# Last update not found
# 22 hrs ago
# 4 hrs ago
# Last update not found
# 12 hrs ago
# 16 hrs ago
# 6 hrs ago
# 44 mins ago
# 12 hrs ago
# 4 hrs ago
# 16 hrs ago

# %%
# Ambil elemen h3 atau h2 dari halaman
headlines = soup.select('h3') + soup.select('h2')

# List untuk menyimpan deskripsi link
link_list = []

for headline in headlines:
    # Cari elemen parent <a> untuk konteks headline
    link_tag = headline.find_parent('a')

    if link_tag:
        link = link_tag['href']
        # Jika tautannya relatif, tambahkan domain utama BBC
        full_link = f"https://www.bbc.com{link}" if link.startswith('/') else link
        link_list.append(full_link)  # Tambahkan ke list

# https://www.bbc.com/sport/football/live/ce8d2380yyet
# https://www.bbc.com/sport/football/articles/c2lnkd7r2y1o
# https://www.bbc.com/sport/boxing/articles/c4gr2gm51zpo
# https://www.bbc.com/sport/cricket/articles/cn7yx3y1rpxo
# https://www.bbc.com/sport/football/articles/ce9j2ky7412o
# https://www.bbc.com/sport/football/articles/c2lnkd7r2y1o
# https://www.bbc.com/sport/football/articles/c4g4rr1llzvo
# https://www.bbc.com/sport/boxing/articles/c4gr2gm51zpo

# %%
# Cari semua elemen gambar
image_tags = soup.find_all('img')

# List untuk menyimpan URL gambar
image = []

# Ambil URL gambar
for img in image_tags:
    image_src = img.get('src')
    if image_src:
        # Jika src relatif, tambahkan domain BBC
        if image_src.startswith('//'):
            full_image_url = f"https:{image_src}"  # Tambahkan "https:" di depan
        elif image_src.startswith('/'):
            full_image_url = f"https://www.bbc.com{image_src}"  # Tambahkan domain utama
        else:
            full_image_url = image_src  # Sudah berupa URL

        # Filter out PNG images
        if not full_image_url.lower().endswith('.png'):
            image.append(full_image_url)

# Cek apakah URL ditemukan
if not image:
    print("Tidak ada URL gambar yang ditemukan.")
else:
    # Tampilkan URL gambar
    for url in image:
        print(url)
# Out:
# https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/e4e4/live/8c9784e0-7bd7-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/bb05/live/6a9a8220-7be6-11ef-a067-535ff32592e2.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/ecd7/live/b7fadca0-7bdb-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/bb05/live/6a9a8220-7be6-11ef-a067-535ff32592e2.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/a59b/live/82841210-7be7-11ef-a835-4d10169418a5.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/fb06/live/578a81d0-7ba5-11ef-a7c4-7da8e96a4f49.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/f4d2/live/0e318220-7bd9-11ef-b02d-c5f3b724a1ea.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/ecd7/live/b7fadca0-7bdb-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/c95d/live/c58d9a80-7b70-11ef-b487-93d163dc71aa.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/e5b5/live/762b7330-7b94-11ef-b9f4-1b8ff515db57.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/e457/live/d48d2d60-6f55-11ef-8c1a-df523ba43a9a.png.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/208d/live/63e58420-7736-11ef-b02d-c5f3b724a1ea.png.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/8a70/live/dd4472c0-7b52-11ef-b282-4535eb84fe4b.jpg.webp
# https://ichef.bbci.co.uk/news/480/cpsprodpb/198f/live/abbbb570-7b15-11ef-8c1a-df523ba43a9a.jpg.webp
